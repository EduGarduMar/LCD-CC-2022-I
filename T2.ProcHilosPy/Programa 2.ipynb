# %%
import multiprocessing as mp

def tarea(nombre):
    print("Hola", nombre)

if __name__ == "__main__":
    p = mp.Process(target=tarea, args=("oscar",))
    p.start()
    p.join()
# Out:
# Hola oscar

# %%
import time
import multiprocessing as mp

nums_res = []

def calc_cuad(numeros):
    global nums_res
    for n in numeros:
        print('cuadrado:', n * n )
        nums_res.append(n * n)

    #print("Resultado del proceso:", nums_res)


nums = range(10)

t = time.time()
p1 = mp.Process(target=calc_cuad, args=(nums,))

p1.start()
p1.join()

print("Tiempo de ejecución: ", time.time()-t)
print("Resultado del proceso:", nums_res)
print("Finaliza ejecución")
# Out:
# cuadrado: 0
# cuadrado: 1
# cuadrado: 4
# cuadrado: 9
# cuadrado: 16
# cuadrado: 25
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cuadrado: 81
# Tiempo de ejecución:  0.08527064323425293
# Resultado del proceso: []
# Finaliza ejecución

# %%
import os

print("module name", __name__)
print("parent process:", os.getppid())
print("process id:", os.getppid())
# Out:
# module name __main__
# parent process: 52
# process id: 52

# %%
def info(titulo):
    print(titulo)
    print("module name", __name__)
    print("parent process:", os.getppid())
    print("process id:", os.getppid())

def f(nombre):
    info("funcion f")
    print("hello", nombre)
    print("--------")

info("Primera linea")
p = mp.Process(target=f, args=("oscar",))
p.start()
p.join()
# Out:
# Primera linea
# module name __main__
# parent process: 52
# process id: 52
# funcion f
# module name __main__
# parent process: 65
# process id: 65
# hello oscar
# --------
